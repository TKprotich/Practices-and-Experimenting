# %%
import tabula
import numpy as np
import pandas as pd

# %%
# file = 'Football-1596465680878.pdf'

# tabula.convert_into(file, "Football0308.csv",  pages = 'all')

# %%
df = pd.read_csv("Football0308.csv", parse_dates=[1], skipinitialspace=True, skiprows=1 )

# %%
df.columns.get_loc('Unnamed: 3')
# Out:
# 3

# %%
for i in range(len(df)):
    message = "{} is beating {}".format(df.iloc[i, 'Unnamed: 3'])

# %%
df
# Out:
#            DATE   TIME GAME ID                        Unnamed: 3 MATCH  \
# 0           NaN    NaN     NaN                               NaN   NaN
# 1    03/08/2020  17:12   48745  PARIS SAINT-GERMAIN (CHELLOVEKK)    vs
# 2    03/08/2020  17:12   83599    FC BAYERN MUNICH (BLACKSTAR98)    vs
# 3    03/08/2020  17:20   85685                    GAMBIT ESPORTS    vs
# 4    03/08/2020  17:22   89516      FC GIRONDINS BORDEAUX (STDM)    vs
# ..          ...    ...     ...                               ...   ...
# 99   04/08/2020  12:30   15163                         W. SYDNEY    vs
# 100  04/08/2020  13:00   42728                  SHENZHEN HONZUAN    vs
# 101  04/08/2020  15:00   47467                    JIANGSU SUNING    vs
# 102  04/08/2020  18:00   36116                   SHABAB AL ORDUN    vs
# 103  04/08/2020  18:00   72929                         DINAMO B.    vs
#
#                  Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# ...

# %%
notneed = list(df.columns[9:])

# %%
notneed
# Out:
# ['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']

# %%
df.drop(axis =1, columns = notneed, inplace=True,)

# %%
df.columns[3:]
# Out:
# Index(['Unnamed: 3', 'MATCH', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8'],
#       dtype='object')

# %%
df.rename(columns={'Unnamed: 3': 'Home', 'Unnamed: 5': 'Away', 'Unnamed: 6': 'odds1', 'Unnamed: 7': 'oddsx', 'Unnamed: 8': 'odds2', }, inplace=True,)

# %%
df.drop([0], inplace=True)

# %%
df
# Out:
#            DATE   TIME GAME ID                              Home MATCH  \
# 1    03/08/2020  17:12   48745  PARIS SAINT-GERMAIN (CHELLOVEKK)    vs
# 2    03/08/2020  17:12   83599    FC BAYERN MUNICH (BLACKSTAR98)    vs
# 3    03/08/2020  17:20   85685                    GAMBIT ESPORTS    vs
# 4    03/08/2020  17:22   89516      FC GIRONDINS BORDEAUX (STDM)    vs
# 5    03/08/2020  17:22   94240     PARIS SAINT GERMAIN (UNKNOWN)    vs
# ..          ...    ...     ...                               ...   ...
# 99   04/08/2020  12:30   15163                         W. SYDNEY    vs
# 100  04/08/2020  13:00   42728                  SHENZHEN HONZUAN    vs
# 101  04/08/2020  15:00   47467                    JIANGSU SUNING    vs
# 102  04/08/2020  18:00   36116                   SHABAB AL ORDUN    vs
# 103  04/08/2020  18:00   72929                         DINAMO B.    vs
#
#                         Away  odds1 oddsx  odds2
# 1      SSC NAPOLI (FEARGGWP)   3.15  2.50   2.75
# ...

# %%
df.sort_values(by=['odds1'], ascending=True)
# Out:
#           DATE   TIME  GAME ID                               Home  MATCH  \
# 57         NaN    NaN      NaN                                NaN    NaN
# 79  04/08/2020  00:40    39978      UNIVERSIDAD DE CHILE (LIMA_R)     vs
# 21  03/08/2020  18:00    10276                        RB SALZBURG     vs
# 73  03/08/2020  23:40    92719                   SANTOS (F_MATHI)     vs
# 70  03/08/2020  23:20    66006  UNIVERSIDAD CATOLICA (CASSIANO_F)     vs
# ..         ...    ...      ...                                ...    ...
# 82  04/08/2020  01:20    78643               ALIANZA LIMA (DRE_S)     vs
# 95  04/08/2020  03:00    83717              RACING ARG (VINICAI_)     vs
# 39  03/08/2020  19:00    89023               PARNU JALGPALLIKLUBI     vs
# 55         NaN    NaN      NaN                                NaN    NaN
# 56        DATE   TIME  GAME ID                                NaN  MATCH
#
#                              Away  odds1  oddsx  odds2
# ...

# %%
df
# Out:
#            DATE   TIME GAME ID                           Home  \
# 1    01/08/2020  23:56   53897  FC BAYERN MUNICH (INDRA13_27)
# 2    01/08/2020  23:56   43248   BAYER 04 LEVERKUSEN (THIAGO)
# 3    01/08/2020  23:56   77619             1. FC KOLN (APHEX)
# 4    01/08/2020  23:56   39930           WERDER BREMEN (STDM)
# 5    02/08/2020  00:00   40736      CHATTANOOGA RED WOLVES SC
# ..          ...    ...     ...                            ...
# 99   02/08/2020  10:00   99674                       EHIME FC
# 100  02/08/2020  10:20   21172                   RUB FC KAZAN
# 101  02/08/2020  10:45   76072                    EZ1 EZ1D 11
# 102  02/08/2020  11:00   67391                  YSCC YOKOHAMA
# 103  02/08/2020  11:00   95236                     SAGAMIHARA
#
#                                       Away  odds1 oddsX  odds2
# 1         vs BORUSSIA DORTMUND (FLESHKA77)   2.50  4.60   2.25
# 2                   vs RB LEIPZIG (SKRIPP)   2.95  4.20   2.10
# ...
