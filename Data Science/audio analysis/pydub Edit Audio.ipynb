# %%
import os
import random
from pydub import AudioSegment
from pydub.playback import play

# %%
PATH = "C:/Users/user/Documents/notification/Pursuit - AShamaluevMusic.mp3"

# %%
song = AudioSegment.from_mp3(PATH)

# %%
song1 = song[:22000] + song[143000:]

# %%
song1
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
song2 = song[22000:44000] + song[143000:]

# %%
song2
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
song3 = song[:5000]

# %%
song3
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
