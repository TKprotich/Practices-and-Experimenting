# %%
import os
import random
from pydub import AudioSegment
from pydub.playback import play

# %%
song = random.choice([i for i in os.listdir("C:/Users/user/Music") if i.endswith(".mp3")])

# %%
PATH = "C:/Users/user/Music"

# %%
pathtosong = PATH + "/" + song

# %%
np.seed(100)
selected_song = AudioSegment.from_mp3(pathtosong)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-fa228563b30c> in <module>
# ----> 1 np.seed(100)
#       2 selected_song = AudioSegment.from_mp3(pathtosong)
#
# NameError: name 'np' is not defined

# %%
play(selected_song)

# %%
[PATH + "/" + i for i in os.listdir("C:/Users/user/Music") if i.endswith(".mp3")]
# Out:
# ['C:/Users/user/Music/Caleb and Kelsey.mp3',
#  'C:/Users/user/Music/Casting_Crowns_-_Voice_Of_Truth(nicegospel.com).mp3',
#  'C:/Users/user/Music/Jesus-Lover-of-My-soul.mp3',
#  'C:/Users/user/Music/Koffee-Burning.mp3',
#  'C:/Users/user/Music/Koffee-Rapture.mp3',
#  'C:/Users/user/Music/Koffee-Throne.mp3',
#  'C:/Users/user/Music/Koffee-W-feat-Gunna-(JustNaija.com).mp3',
#  'C:/Users/user/Music/KoffeeidontcareRemix.mp3',
#  'C:/Users/user/Music/Michael_W._Smith_-_Ancient_Words.mp3',
#  'C:/Users/user/Music/read1.mp3',
#  'C:/Users/user/Music/Rudy_rooster_crowing-Shelley-1948282641.mp3',
#  'C:/Users/user/Music/Tory-Lanez-ft-Koffee-Toast.mp3',
#  'C:/Users/user/Music/tubidy.blue_Casting Crowns - Voice of Truth [LYRICS].mp3',
#  'C:/Users/user/Music/tubidy.blue_Fanuel Sedekia Injili Ya Yesu.mp3',
#  'C:/Users/user/Music/tubidy.blue_GUC - All That Matters (Lyrics Video) DanzibaServices.mp3',
# ...

# %%
playlist_songs = [AudioSegment.from_mp3(PATH + "/" + i) for i in os.listdir("C:/Users/user/Music") if i.endswith(".mp3")]

# %%
combinedn = playlist_songs[0]
for song in playlist_songs[1:]:
    combinedn = combinedn.append(song, crossfade=960)
combinedn.export(PATH+"/combined.mp3", format = "mp3")
# Out:
# <_io.BufferedRandom name='C:/Users/user/Music/combined.mp3'>

# %%
help(AudioSegment)
# Out:
# Help on class AudioSegment in module pydub.audio_segment:
#
# class AudioSegment(builtins.object)
#  |  AudioSegment(data=None, *args, **kwargs)
#  |
#  |  AudioSegments are *immutable* objects representing segments of audio
#  |  that can be manipulated using python code.
#  |
#  |  AudioSegments are slicable using milliseconds.
#  |  for example:
#  |      a = AudioSegment.from_mp3(mp3file)
#  |      first_second = a[:1000] # get the first second of an mp3
#  |      slice = a[5000:10000] # get a slice from 5 to 10 seconds of an mp3
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, arg)
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __getitem__(self, millisecond)
#  |
#  |  __hash__(self)
#  |      Return hash(self).
#  |
#  |  __init__(self, data=None, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  __len__(self)
# ...

# %%
import datetime as dt

# %%
help(dt)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
#      |      Formats self with strftime.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
# ...

# %%
ttd = dt.datetime.today()

# %%
ttd
# Out:
# datetime.datetime(2020, 7, 17, 22, 57, 13, 197748)
